# %% [markdown]
# # Supply Chain Exploratory Analysis
#
# Run `python scripts/run_pipeline.py all` first, then use this notebook to inspect the generated DuckDB tables and dashboard-ready CSV outputs. The automated HTML EDA report is generated by `src.analytics.build_eda_report`.
